# %% [markdown]
# # ProfetiQ Forecaster Pipeline\n\nConfigure `PROFETIQ_FORECASTER_API_TOKEN`, then run a model-level forecast.

# %%
from profetiq_forecaster import ProfetiQForecaster\n\nclient = ProfetiQForecaster()\nentities = client.entities(level='model', segment='premium')\nentities[:3]\n

# %%
forecast = client.forecast(level='model', entity_id=entities[0]['entity_id'], horizons=[1, 2, 3])\nforecast['points']\n
